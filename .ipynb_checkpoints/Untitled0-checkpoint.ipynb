# %%
# %matplotlib inline
import pylab
import numpy as np
from IPython.display import display, Math, Latex

# %%
data=[]
with open("etot.txt","r") as file:
    for i in file.readlines():
        data.append(i.split())

# %%
pylab.plot([float(x[0]) for x in data],[float(x[4]) for x in data])
pylab.plot([float(x[0]) for x in data],[float(x[3]) for x in data])
pylab.plot([float(x[0]) for x in data],[float(x[2])for x in data])
pylab.plot([float(x[0]) for x in data],[float(x[1])for x in data])
max([float(x[4]) for x in data])-min([float(x[4]) for x in data])
# Out:
# 0.023426000000000613

# %%
data2=[]
with open("euler.txt","r") as file:
    for i in file.readlines():
        data2.append(i.split())
data3=[]
with open("leapfrog.txt","r") as file:
    for i in file.readlines():
        data3.append(i.split())
data4=[]
with open("nowe.txt","r") as file:
    for i in file.readlines():
        data4.append(i.split())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-9dc501727a7b> in <module>()
#       1 data2=[]
# ----> 2 with open("euler.txt","r") as file:
#       3     for i in file.readlines():
#       4         data2.append(i.split())
#       5 data3=[]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'euler.txt'

# %% [markdown]
# $$ x = \sum $$

# %%
pylab.plot([float(x[0]) for x in data2],[float(x[4]) for x in data2])
pylab.plot([float(x[0]) for x in data3],[float(x[4]) for x in data3])

# %%
pylab.plot([float(x[0]) for x in data4],[float(x[2]) for x in data4])
pylab.plot([float(x[0]) for x in data4],[float(x[3]) for x in data4])
pylab.plot([float(x[0]) for x in data4],[float(x[4]) for x in data4])

# %%
pylab.plot([float(x[1]) for x in data4],[float(x[5]) for x in data4])

# %%
data=[]
with open("output2","r") as file:
    for i in file.readlines():
        data.append(i.split())

# %%
# %matplotlib inline
import pylab
import numpy as np

# %%
x=np.array([float(x[0]) for x in data])
y=np.array([float(x[1]) for x in data])
z=np.array([float(x[2]) for x in data])
tot=x*x+y*y+z*z/80

# %%
n, bins, patches = pylab.hist(x, 50, normed=1, histtype='step')
n, bins, patches = pylab.hist(y, 50, normed=1, histtype='step')
n, bins, patches = pylab.hist(z, 50, normed=1, histtype='step')

# %%
n, bins, patches = pylab.hist(tot, 50, normed=1, histtype='step')

# %%
pylab.plot(x)
pylab.plot(y)
pylab.plot(z)

# %%
vectors=[]
for i in data:
    vectors.append(np.array([float(i[0]),float(i[1]),float(i[2])]))

# %%
sum(vectors)/len(vectors)
# Out:
# array([-0.03566976, -0.01048122,  0.00174013])

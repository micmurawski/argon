# %%
# %matplotlib inline
import pylab
import numpy as np
from IPython.display import display, Math, Latex

# %%
data=[]
with open("etot.txt","r") as file:
    for i in file.readlines():
        data.append(i.split())

# %%
pylab.plot([float(x[0]) for x in data],[float(x[4]) for x in data])
max([float(x[4]) for x in data])-min([float(x[4]) for x in data])
# Out:
# 0.023426000000000613

# %%
pylab.plot([float(x[0]) for x in data],[float(x[3]) for x in data])
pylab.ylabel('E [kJ/mol]')
pylab.xlabel('t [ps]')
pylab.plot([float(x[0]) for x in data],[float(x[2])for x in data])
pylab.plot([float(x[0]) for x in data],[float(x[4])for x in data])
#pylab.plot([float(x[0]) for x in data],[float(x[1])for x in data])
sum([float(x[2])for x in data])

# %% [markdown]
# $$ x = \sum $$

# %%
pylab.plot([float(x[0]) for x in data],[21*float(x[5]) for x in data])
pylab.plot([float(x[0]) for x in data],[float(x[1]) for x in data])

# %%
data2=[]
with open("125.txt","r") as file:
    for i in file.readlines():
        data2.append(i.split())

# %%
pylab.plot([float(x[0]) for x in data2],[15.6*float(x[5]) for x in data2])
pylab.plot([float(x[0]) for x in data2],[float(x[1]) for x in data2])

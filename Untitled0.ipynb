# %%
# %matplotlib inline
import pylab
import numpy as np
from IPython.display import display, Math, Latex
t=[51.486,4.214,0.415,0.053,0.015]

# %%
data=[]
seria=[]
tests=["test_6.txt","test_5.txt","test_4.txt","test_3.txt","test_2.txt"]
for test in tests:
    with open(test,"r") as file:
        for i in file.readlines():
            seria.append(i.split())
        print('ok')
        data.append(seria)
        seria=[]
# Out:
# ok
# ok
# ok
# ok
# ok

# %%
for ser,lab in zip(data,tests):
    pylab.plot([float(x[0]) for x in ser],[float(x[1]) for x in ser],label=lab)
pylab.legend()
pylab.ylabel('E [kJ/mol]')
pylab.xlabel('t [ps]')

# %% [markdown]
# $$ x = \sum $$

# %%
data=[]
seria=[]
tests=["avs0.dat","avs10.dat","avs100.dat","avs400.dat","avs1000.dat"]
for test in tests:
    with open(test,"r") as file:
        for i in file.readlines()[1:]:
            seria.append(i.split())
        print('ok')
        data.append(seria)
        seria=[]
# Out:
# ok
# ok
# ok
# ok
# ok

# %%
for ser,lab in zip(data,tests):
    pylab.plot([float(x[0]) for x in ser],[float(x[1]) for x in ser],label=lab)
pylab.legend()
pylab.ylabel('E [kJ/mol]')
pylab.xlabel('t [ps]')

# %%
pylab.plot([float(x[0]) for x in data2],[15.6*float(x[5]) for x in data2])
pylab.plot([float(x[0]) for x in data2],[float(x[1]) for x in data2])

# %%
pylab.plot([float(x[3]) for x in data],[float(x[4]) for x in data])

# %%
pylab.plot(t)
